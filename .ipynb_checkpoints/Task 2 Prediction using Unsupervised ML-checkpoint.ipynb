# %% [markdown]
# # The Spark Foundation #GRIPJUNE21

# %% [markdown]
# ## Task 2 Prediction using Unsupervised ML

# %% [markdown]
# ### by hafedh hichri

# %%
import warnings 
warnings.filterwarnings("ignore")

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('./Iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # data preprocessing

# %%
df.drop('Id',axis=1,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder 
le = LabelEncoder()
df['Species'] = le.fit_transform(df['Species'])

# %% [markdown]
# # feature engineering

# %%
#in this part we can add 2 features on accordance to the sepal volume (volume of a cylinder) 
# and the the surface area of a cut on the petal

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from math import pi 
#cylinder volume = r^2 * pi * hight
df['sepal_vol_cm3'] = (( (df['SepalWidthCm']/2) **2)*pi)  *  df['SepalLengthCm'] 

df['petal_sidesurface_air']= df['PetalLengthCm'] * df['PetalWidthCm']

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species  \
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0
#
#    sepal_vol_cm3  petal_sidesurface_air
# 0      49.067750                   0.28
# 1      34.636059                   0.28
# 2      37.799643                   0.26
# 3      34.719311                   0.30
# 4      50.893801                   0.28

# %% [markdown]
# # EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   SepalLengthCm          150 non-null    float64
#  1   SepalWidthCm           150 non-null    float64
#  2   PetalLengthCm          150 non-null    float64
#  3   PetalWidthCm           150 non-null    float64
#  4   Species                150 non-null    int32
#  5   sepal_vol_cm3          150 non-null    float64
#  6   petal_sidesurface_air  150 non-null    float64
# dtypes: float64(6), int32(1)
# memory usage: 7.7 KB

# %%
df.isnull().sum()
# Out:
# SepalLengthCm            0
# SepalWidthCm             0
# PetalLengthCm            0
# PetalWidthCm             0
# Species                  0
# sepal_vol_cm3            0
# petal_sidesurface_air    0
# dtype: int64

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm     Species  \
# count     150.000000    150.000000     150.000000    150.000000  150.000000
# mean        5.843333      3.054000       3.758667      1.198667    1.000000
# std         0.828066      0.433594       1.764420      0.763161    0.819232
# min         4.300000      2.000000       1.000000      0.100000    0.000000
# 25%         5.100000      2.800000       1.600000      0.300000    0.000000
# 50%         5.800000      3.000000       4.350000      1.300000    1.000000
# 75%         6.400000      3.300000       5.100000      1.800000    2.000000
# max         7.900000      4.400000       6.900000      2.500000    2.000000
#
#        sepal_vol_cm3  petal_sidesurface_air
# count     150.000000             150.000000
# mean       43.446341               5.793133
# std        13.079166               4.713499
# min        15.707963               0.110000
# 25%        34.813952               0.420000
# ...

# %%
sns.pairplot(df)

# %%
corr = df.corr()
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
for col in df.columns:
    df[[col]].boxplot()
    plt.show()

# %% [markdown]
# ### ==> scaling needed

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
df[['sepal_vol_cm3']] = sc.fit_transform(df[['sepal_vol_cm3']])
df[['petal_sidesurface_air']] = sc.fit_transform(df[['petal_sidesurface_air']])

# %%
df.nunique()
# Out:
# SepalLengthCm             35
# SepalWidthCm              23
# PetalLengthCm             43
# PetalWidthCm              22
# Species                    3
# sepal_vol_cm3            115
# petal_sidesurface_air    101
# dtype: int64

# %%
df['Species'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='Species'>

# %%
for col in df.select_dtypes('float'):
    plt.figure()
    df[[col]].hist()

# %%
for col in df.columns:
    plt.figure()
    sns.distplot(df[col],color='green')

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species  \
# 0              5.1           3.5            1.4           0.2        0
# 1              4.9           3.0            1.4           0.2        0
# 2              4.7           3.2            1.3           0.2        0
# 3              4.6           3.1            1.5           0.2        0
# 4              5.0           3.6            1.4           0.2        0
# ..             ...           ...            ...           ...      ...
# 145            6.7           3.0            5.2           2.3        2
# 146            6.3           2.5            5.0           1.9        2
# 147            6.5           3.0            5.2           2.0        2
# 148            6.2           3.4            5.4           2.3        2
# 149            5.9           3.0            5.1           1.8        2
#
#      sepal_vol_cm3  petal_sidesurface_air
# 0         0.431239              -1.173566
# ...

# %% [raw]
# the elbow method :

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.cluster import KMeans

scores = []
range_values = range(1,10)

for i in range_values:
    kmeans = KMeans(n_clusters = i)
    kmeans.fit(df) 
    scores.append(kmeans.inertia_)

plt.plot(scores,'bx-')

# %% [markdown]
# # without PCA

# %%
kmeans = KMeans(3,random_state=42)
kmeans.fit(df)
y_pred = kmeans.predict(df)

# %%
print(f'inertia = {kmeans.inertia_}')
# Out:
# inertia = 216.45474857634207

# %%
sns.scatterplot(x='sepal_vol_cm3',y='petal_sidesurface_air',data=df ,
                hue=y_pred,palette=['red','green','blue'])
# Out:
# <AxesSubplot:xlabel='sepal_vol_cm3', ylabel='petal_sidesurface_air'>

# %%
df_final = df 
df_final['predicted'] = y_pred
sns.pairplot(df_final,hue='predicted',palette=['r','g','b'])

# %%
sns.histplot(data=df_final,x='predicted',hue='Species',palette=['r','g','b'])
# Out:
# <AxesSubplot:xlabel='predicted', ylabel='Count'>

# %% [markdown]
# # after PCA

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# PCA has the role of englobing the original data using less columns 
# thus less variables with almost the same amount of data

# %% [markdown]
# ### from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=3,random_state=42)
pca.fit(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-a6a03f037fa0> in <module>
# ----> 1 pca = PCA(n_components=3,random_state=42)
#       2 pca.fit(df)
#
# NameError: name 'PCA' is not defined

# %%
print(f'{sum(pca.explained_variance_ratio_):.4f} of the data is kept')

# %%
#99% of the informations from df is now located in only 3 columns

# %%
df_pca = pd.DataFrame(pca.transform(df),columns=['pca1','pca2','pca3'])

# %%
df_pca

# %%
kmeans_pca = KMeans(n_clusters=3,random_state=42)
kmeans_pca.fit(df_pca)
y_pred = kmeans_pca.predict(df_pca)
df_pca['predict'] = y_pred

# %%
print(f'inertia = {kmeans_pca.inertia_}')

# %%
sns.pairplot(df_pca,hue='predict',palette=['r','g','b'])

# %%
print(f'inertia without PCA= {kmeans.inertia_  :.4f}')
print(f'inertia with PCA = {kmeans_pca.inertia_ :.4f}')

# %%
#using PCA helped us decrease the inirtia
